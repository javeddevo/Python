# %%
import pandas as pd
import sqlalchemy as sal
engine=sal.create_engine("mssql+pyodbc://LAPTOP-MRKDUIFF\SQLEXPRESS01/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER")
conn=engine.connect()

# %%
import pandas as pd 
def extract():
    df_orders=pd.read_csv("orders.txt")
    df_returns=pd.read_csv("returns.txt")
    return df_orders,df_returns

# %%
def transform(orders,returns):
    df=pd.merge(orders,returns,how="inner",left_on="order_id",right_on="order_id")
    return df

# %%
#load
def load(df):
    df.to_sql("orders_final",con=conn,index=False,if_exists="replace")
    conn.commit()

# %%
#extract
df_orders,df_returns=extract()
#transform
df=transform(df_orders,df_returns)
#load
load(df)

# %%
# read_sql_query

# %%
df=pd.read_sql_query("select * from orders_final",conn)
df
# Out:
#            order_id  order_date      customer_name         city  \
# 0    CA-2018-100762  2018-11-24         Nat Gilpin      Jackson
# 1    CA-2018-100867  2018-10-19  Eugene Hildebrand     Lakewood
# 2    CA-2018-102652  2018-04-06         Andy Yotov  Los Angeles
# 3    CA-2018-103373  2018-05-18      Bruce Stewart    Cleveland
# 4    CA-2018-103744  2018-02-23      Michael Grace      El Paso
# ..              ...         ...                ...          ...
# 291  US-2021-136679  2021-11-14       Xylona Preis     Pasadena
# 292  US-2021-147886  2021-03-28      Dave Hallsten    Fairfield
# 293  US-2021-147998  2021-05-19       Sue Ann Reed     San Jose
# 294  US-2021-151127  2021-05-22          Rob Lucas  Los Angeles
# 295  US-2021-155999  2021-08-07         Jay Kimmel    San Diego
#
#             category       product_id    sales    profit Return Reason
# 0    Office Supplies  OFF-AR-10000380  151.920   45.5760   Bad Quality
# ...
